# %%
# Exemplo básico
from mt5_expert_runner import run_mt5_live_ea

# %%
# Configurar EA
run_mt5_live_ea(
    expert_name='sino\\ZScoreStrategy',
    expert_params_file='sino\\prod\\WIN$N_WSP$N_RSI_RSI_RATIO_7066963457615126378.set',
    symbol='WINV25',
    timeframe='M1',
)
# Out:
# 🚀 Iniciando MT5 Live Trading...
#    Expert: sino\ZScoreStrategy
#    Symbol: WINV25
#    Timeframe: M1
#    Parameters: sino\prod\WIN$N_WSP$N_RSI_RSI_RATIO_7066963457615126378.set
#    Config: live_trading_config_WINV25_20250902_181441.ini
